# %% [markdown]
# # Example Usage

# %% [markdown]
# ## Boilerplate

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

from pathlib import Path
from scipy import stats

# Import library
from nems_fingerprint import *
from nems_fingerprint.euler_bernoulli_beam import displacement as ebb_disp

# Plotting
import bokeh
import bokeh.palettes as palettes

from bokeh.io import show, output_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.layouts import Column, gridplot

palette = palettes.Category10[10]

output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="db2ce98a-70a3-4573-8808-c738ccecc10b">Loading BokehJS ...</span>
#     </div>

# %%
# %%html
# <!-- So that markdown cells don't stretch across the whole screen -->
# <style>
# .jp-RenderedMarkdown {
#     max-width: 700px;
# }
# .jp-MarkdownCell {
#     max-width: 900px;
# }
# </style>
# Out:
# <!-- So that markdown cells don't stretch across the whole screen -->
# <style>
# .jp-RenderedMarkdown {
#     max-width: 700px;
# }
# .jp-MarkdownCell {
#     max-width: 900px;
# }
# </style>

# %%
# Generic plot settings

line_settings = dict(
    line_width=2,
    muted_alpha=0.1
)

fig_settings = dict(
    width=500,
    height=350
)

tool_settings = dict(
    toolbar_location=None,
    tools=[]
)

# %% [markdown]
# ## Euler-Bernoulli Beam Simulation

# %%
ebb_sim = EBBSimulation(
    boundary_type='clamped-free',
    mode_indices=[1, 2, 3],
    mass_dist=Distribution.constant(1.0),
        position_dist=Distribution.uniform(0.0, 1.0),
    noise_dist=Distribution.normal(0.0, 0.02)
)

# Using Original Implementation
learning_events = ebb_sim.sample(n_events=1000)
mass_predictor_0 = MassPredictNN(learning_events)

measurement_phase_shifts = ebb_sim.sample(n_events=2000).freq_shifts
masses_0 = mass_predictor_0(measurement_phase_shifts)

# %%
# Abstract KD-Tree
mass_predictor_1 = NNPredictor(learning_events)
masses_1 = mass_predictor_1(measurement_phase_shifts)

# Abstract SKLearn
mass_predictor_2 = NNPredictor(learning_events)
masses_2 = mass_predictor_2(measurement_phase_shifts)

# %%
print(np.array_equal(masses_0, masses_1), np.array_equal(masses_1, masses_2))
# Out:
# True True

# %%
# Abstract SKLearn
mass_predictor_3 = NNPredictorCV(learning_events)
masses_3 = mass_predictor_3(measurement_phase_shifts)
# Out:
# model_trained

# %%
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
masses = masses_3
hist, bin_edges = np.histogram(np.log(masses), density=True, bins=200, range=(-1, 1))
masses_sorted = np.sort(masses)
freq_shifts = learning_events.freq_shifts

settings = dict(margin=20)

p1 = figure(
    x_axis_label='$$\Delta f_1 / f_1$$',
    y_axis_label='$$\Delta f_2 / f_2$$',
    **settings
)
p1.scatter(freq_shifts[:, 0], freq_shifts[:, 1])

p2 = figure(
    x_axis_label='$$\Delta f_1 / f_1$$',
    y_axis_label='$$\Delta f_3 / f_3$$',
    **settings
)
p2.scatter(freq_shifts[:, 0], freq_shifts[:, 2])


p3 = figure(
    x_axis_label='sample # / N',
    y_axis_label='mass',
    y_axis_type='log',
    **settings
)
p3.scatter(np.arange(len(masses)) / len(masses), masses_sorted)


p4 = figure(
    x_axis_label='log(Mass)',
    y_axis_label='pdf',
    **settings
)
p4.quad(top=hist, bottom=0, left=bin_edges[:-1], right=bin_edges[1:])



for p in (p1, p2):
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"

ps = [p1, p2, p3, p4]
gs = gridplot(ps, ncols=2, width=400, height=400)
show(gs)
# Out:
#   <div id="a4cde472-9ed1-427d-bf12-a151160cfd28" data-root-id="p2358" style="display: contents;"></div>

# %%
BM = BootstrapModel(learning_events, NNPredictor, None, 1000, 1)
bootstrap_masses = BM(measurement_phase_shifts)
bootstrap_mean_masses = np.mean(bootstrap_masses, axis = 1)
bootstrap_mean_std = 10*np.std(bootstrap_masses, axis = 1)

# %%
hist, bin_edges = np.histogram(np.log(bootstrap_mean_masses), density=True, bins=200, range=(-1, 1))
mean_masses_sorted = np.sort(bootstrap_mean_masses)


# Sort the values of mean_val and adjust std_val accordingly
sort_indices = np.argsort(bootstrap_mean_masses)
mean_val_sorted = bootstrap_mean_masses[sort_indices]
std_val_sorted = bootstrap_mean_std[sort_indices]

# Generate upper and lower values for the error bars
upper = mean_val_sorted + std_val_sorted
lower = mean_val_sorted - std_val_sorted

# Indices
indices = np.arange(len(mean_val_sorted))



settings = dict(margin=20)

p3 = figure(
    x_axis_label='sample # / N',
    y_axis_label='mass',
    y_axis_type='log',
    **settings
)
p3.scatter(indices, mean_masses_sorted)
p3.segment(indices, upper, indices, lower, line_color='black')

p4 = figure(
    x_axis_label='log(Mass)',
    y_axis_label='pdf',
    **settings
)
p4.quad(top=hist, bottom=0, left=bin_edges[:-1], right=bin_edges[1:])



ps = [p3, p4]
gs = gridplot(ps, ncols=2, width=400, height=400)
show(gs)
# Out:
#   <div id="acfb4499-596b-4f3e-96b3-15ec43980f30" data-root-id="p1802" style="display: contents;"></div>

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined
